# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

mat_path = '/mnt/c/Users/sudha/Downloads/2024_05_02_exp5_66.mat'

with h5py.File(mat_path, 'r') as f:
    ch1_lt_img = np.array(f['Ch1LTImg'])

# Remove singleton dimensions if present
ch1_lt_img = np.squeeze(ch1_lt_img)

print('Ch1LTImg shape:', ch1_lt_img.shape)

plt.figure(figsize=(6, 6))
plt.imshow(ch1_lt_img, cmap='aqua')
plt.title('Ch1LTImg')
plt.colorbar(label='Intensity')
plt.axis('off')
plt.show()
# Out:
# Ch1LTImg shape: (491, 200)
